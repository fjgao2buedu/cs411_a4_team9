# %%
# pip install pandas
# pip list

# %%
import pandas

data=pandas.read_csv('./imdb/title.basics.tsv',sep='\t',dtype=str)

# %%
data
# Out:
#             tconst  titleType               primaryTitle  \
# 0        tt0000001      short                 Carmencita
# 1        tt0000002      short     Le clown et ses chiens
# 2        tt0000003      short             Pauvre Pierrot
# 3        tt0000004      short                Un bon bock
# 4        tt0000005      short           Blacksmith Scene
# ...            ...        ...                        ...
# 9707255  tt9916848  tvEpisode              Episode #3.17
# 9707256  tt9916850  tvEpisode              Episode #3.19
# 9707257  tt9916852  tvEpisode              Episode #3.20
# 9707258  tt9916856      short                   The Wind
# 9707259  tt9916880  tvEpisode  Horrid Henry Knows It All
#
#                      originalTitle isAdult startYear endYear runtimeMinutes  \
# 0                       Carmencita       0      1894      \N              1
# 1           Le clown et ses chiens       0      1892      \N              5
# ...
